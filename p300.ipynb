# %%
# Run this command in your terminal
# pip install spotipy BeutifulSoup4 requests

import requests
from bs4 import BeautifulSoup
import spotipy
from spotipy.oauth2 import SpotifyOAuth

url = 'https://sverigesradio.se/avsnitt/p300-hela-listan'
response = requests.get(url)
html_content = response.content

# Parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')
song_elements = soup.select('div.publication-text.text-editor-content p a')

print(len(song_elements))
for song in song_elements:
    print(song.text)
# Out:
# 292
# O-O-H Child - Five stairsteps
# Shake it Out - Florence + The Machine
# Pulling Our Weight - The Radio Dept.
# Common People - Pulp
# Himlen Är Oskyldigt Blå - Ted Gärdestad
# Bam Bam - Sister Nancy
# Green Light - Lorde
# Midnight Train To Georgia - Gladys Knight & The Pips
# N.Y State of Mind - Nas
# Korallreven & Vintergatan - Markus Krunegård
# Bipp - Sophie
# Midnight City - M83
# Never Too Much - Luther Vandross
# Heart Of Glass - Blondie
# Confessions Part II - Usher
# Water No Get Enemy - Fela Kuti
# Thank U, Next - Ariana Grande
# Around The World - Daft Punk
# Alberto Balsalm - Aphex Twin
# Speed King - Deep Purple
# Magnetic City - Silverbullit
# Has It Come To This? - The Streets
# Straight Outta Compton - N.W.A.
# Flyktsoda - Ebba Grön
# Mind Playing Tricks On Me - Geto Boys
# All Tomorrowʹs Parties - The Velvet Underground
# Try Again - Aaliyah
# Last Nite - The Strokes
# Down By The Water - Pj Harvey
# God Save The Queen - Sex Pistols
# Viva La Vida - Coldplay
# Back In Black - AC/D
# C.R.E.A.M. - Wu Tang Clan
# I Wanna Be Adored - The Stone Roses
# Someday We’ll All Be Free - Donny Hathaway
# Thirteen - Big Star
# He Wasnʹt Man Enough - Toni Braxton
# Inner City Life - Goldie
# Du Måste Finnas - Helen Sjöholm
# Ainʹt No Sunshine - Bill Withers
# The Art Teacher - Rufus Wainwright
# Empire State Of Mind - Alicia Keys, Jay-Z
# Iʹm Not In Love - 10cc
# Ultralight Beam - Kanye West
# In League With Satan - Venom
# Hurt - Johnny Cash
# Work - Rihanna & Drake
# River Man - Nick Drake
# Sabotage - Beastie Boys
# Through The Fire - Chaka Khan
# Letʹs Stay Together - Al Green
# In Da Club - 50 Cent
# Agony - Yung Lean
# Stay High (Habits Remix) - Tove Lo
# Instant Crush - Daft Punk, Julian Casablancas
# Best Of You - Foo Fighters
# Be Thankful For What Youʹve Got - Willam Devaughn
# Dance Again - Kite
# The Message - Grandmaster Flash & The Furious Five
# Baba OʹRiley - The Who
# Edge Of Seventeen - Stevie Nicks
# Ghost Town - The Specials
# Africa - Toto
# It Takes A Fool To Remain Sane - The Ark
# Honey - Robyn
# Red Dirt Girl - Emmylou Harris
# Trubbel - Monica Zetterlund
# Changes - 2Pac
# Kelly - Amason
# Your Song - Elton John
# Everybody Wants To Rule The World - Tears For Fears
# Electric - Leila K
# Born Slippy (Nuxx) - Underworld
# Hyper-Ballad - Björk
# Unfinished Sympathy - Massive Attack
# Suspicious Minds - Elvis Presley
# (You Make Me Feel Like) A Natural Woman - Aretha Franklin
# Windowlicker - Aphex Twin
# Thinkin Bout You - Frank Ocean
# Careless Whisper - George Michael
# Iʹm On Fire - Bruce Springsteen
# London Calling - The Clash
# 747 - Kent
#  Youʹve Got A Friend - Carole King
# A Change Is Gonna Come - Sam Cooke
# Toxic - Britney Spears
# Hotel California - Eagles
# Levels - Avicii
# The Winner Takes It All - Abba
# Forever Young - Alphaville
# Frozen - Madonna
# I Will Always Love You - Dolly Parton
# Heartbeats -The Knife
# Killing Me Softly With His Song - Fugees
# Love Will Tear Us Apart - Joy Division
# When Doves Cry - Prince
# This Must Be The Place - Talking Heads
# Smells Like Teen Spirit - Nirvana
# I Will Always Love You - Whitney Houston
# Everywhere - Fleetwood Mac
# Enjoy The Silence - Depeche Mode
# Could You Be Loved - Bob Marley & The Wailers
# Video Games - Lana Del Rey
# Like A Rolling Stone - Bob Dylan
# I Say A Little Prayer - Aretha Franklin
# Wuthering Heights - Kate Bush
# Juicy - The Notorious B.I.G.
# Imagine - John Lennon
# There Is A Light That Never Goes Out -The Smiths
# Paper Planes - M.I.A.
# Billie Jean - Michael Jackson
# Blue Monday - New Order
# Heroes - David Bowie
# Dreams - Fleetwood Mac
# Back To Black - Amy Winehouse
# Bridge Over Troubled Water - Simon & Garfunkel
# One More Time - Daft Punk
# Runaway - Kanye West, Pusha T
# Nothing Compares 2 U - Sinéad O'Connor
# Jolene - Dolly Parton
# Whatʹs Going On - Marvin Gaye
# Life On Mars? - David Bowie
# Bohemian Rhapsody - Queen
# P300
# juryn

# %%
# Setup the Spotify API
# Login here to get your credentials https://developer.spotify.com/dashboard
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id='CLIENT_ID',
    client_secret='CLIENT_SECRET',
    redirect_uri='http://localhost:8080',
    scope='playlist-modify-private'
))

# Define the playlist id
playlist_id = 'PLAYLIST_ID'
track_ids = []

# %%
# Delete any current items in the playlist
currentItems = sp.playlist_items(playlist_id)
for item in currentItems['items']:
    print("deleting ", item['track']['name'])
    track = item['track']
    sp.playlist_remove_all_occurrences_of_items(playlist_id, [track['id']])

# %%
# Search for songs that match the names from the website
for song in song_elements:
    res = sp.search(q=song.text, limit=1, type='track')
    if res['tracks']['items']:
        track_id = res['tracks']['items'][0]['id']
        track_ids.append(track_id)
    else:
        print(f"Track not found: {song.text}")

print(len(track_ids))
# Out:
# 292

# %%
# Add tracks to the playlist
# Not sure how many tracks can be added at once, so I'm adding 10 at a time. It definitely does not handle hundreds at once...
x = 0
for i in range(len(track_ids)//10 + 1):
  sp.playlist_add_items(playlist_id, track_ids[i*10:i*10+10])
  x += 10

print(x)
print("Tracks added to the playlist successfully!")
# Out:
# 300
# Tracks added to the playlist successfully!

# %%
l = [0,1,2,3,4,5]
print(l[5:10])
# Out:
# [5]
